# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd

# %%
#Carga desde un archivo .csv sin indice
df = pd.read_csv('Exportaciones.csv')

# %%
#a) Las exportaciones de “iso3: alb”, y de “h_insurance” mayor a “0.5”
filtro_a = df[(df['iso3'] == 'alb') & (df['h_insurance'] > 0.5)]
print(df_a)
# Out:
#      iso3  year sector_GMatrix  g_primaryagr  g_otherprim  g_energy  \
# 1805  alb  2001      insurance        0.5881       0.1019    0.4346
# 3830  alb  2004      insurance        1.0154       0.2250    1.1321
# 3832  alb  2004      oconsumer        2.5977       0.7691    1.2608
# 6908  alb  2007      insurance        1.4055       0.5598    0.3328
# 6910  alb  2007      oconsumer        3.5501       1.8769    0.3671
# 9986  alb  2011      insurance        1.9300       0.9500    0.3700
# 9988  alb  2011      oconsumer        4.7900       3.0200    0.4100
#
#       g_procfoods  g_bevtobacco  g_textiles  g_clothing  ...  h_finance  \
# 1805       0.6516        0.0306      0.1680      0.4371  ...     0.1104
# 3830       1.1834        0.0820      0.3551      0.7406  ...     0.5105
# 3832       2.9437        0.1398      1.5371      1.8077  ...     0.3095
# 6908       1.5858        0.0938      0.5638      0.9704  ...     1.5957
# ...

# %%
#b) Todas las exportaciones de “sector Gmatrix: insurance“ con “g_procfoods” mayor a “7”
filtro_b= df[(df['sector_GMatrix'] == 'insurance') & (df['g_procfoods'] > 7)]
print(df_b)
# Out:
#       iso3  year sector_GMatrix  g_primaryagr  g_otherprim  g_energy  \
# 50     arg  1997      insurance       33.6523       0.1945   18.3172
# 77     aus  1997      insurance      102.2560      13.0391    6.3998
# 104    aut  1997      insurance        1.1619       0.6656    1.0548
# 131    bel  1997      insurance        5.8961       0.8964    0.6508
# 158    bgd  1997      insurance        1.8448       2.4555    0.1200
# ...    ...   ...            ...           ...          ...       ...
# 13064  usa  2011      insurance      759.4300     101.2600  657.7600
# 13091  ven  2011      insurance       13.2100       5.2000   34.9900
# 13118  vnm  2011      insurance        2.2900       3.0200    2.1900
# 13145  zaf  2011      insurance      387.2100     294.9800  148.8600
# 13172  zmb  2011      insurance        2.1500       1.2900    0.8900
#
#        g_procfoods  g_bevtobacco  g_textiles  g_clothing  ...  h_finance  \
# ...

# %%
#c) Todas las exportaciones de “year: 1997 a 2005”
filtro_c= df[(df['year'] >= 1997) & (df['year'] <= 2005)]
print(df_c)
# Out:
#      iso3  year sector_GMatrix  g_primaryagr  g_otherprim  g_energy  \
# 0     alb  1997     primaryagr       93.3774       0.0143    0.2158
# 1     alb  1997      otherprim        0.0521       5.7779    0.0979
# 2     alb  1997         energy       12.8071       3.0441  195.5730
# 3     alb  1997      procfoods        0.8223       0.0041    0.0706
# 4     alb  1997     bevtobacco        0.0022       0.0003    0.0036
# ...   ...   ...            ...           ...          ...       ...
# 6880  zwe  2004        finance       12.9971       0.2822    0.2540
# 6881  zwe  2004      insurance        2.3389       0.0342    0.0250
# 6882  zwe  2004         obsict       14.5142       0.3718    0.3170
# 6883  zwe  2004      oconsumer        2.3766       0.0570    0.0672
# 6884  zwe  2004      oservices        9.4795       0.9173    0.5526
#
#       g_procfoods  g_bevtobacco  g_textiles  g_clothing  ...  h_finance  \
# 0         25.0267        0.3817      0.1455      0.9488  ...     0.0019
# ...

# %%
#d) Todas las exportaciones con “Vxsharefwd” mayor a “0.5” y con “Vxsharebwd” menor a “0.5”
filtro_d= df[(df['VXsharefwd'] > 0.5) & (df['VXsharebwd'] < 0.5)]
print(df_d)
# Out:
#       iso3  year sector_GMatrix  g_primaryagr  g_otherprim   g_energy  \
# 2      alb  1997         energy       12.8071       3.0441   195.5730
# 3591   uga  2001     primaryagr     2410.5800       2.9207     1.4033
# 4023   ben  2004     primaryagr      782.2470       0.2940     0.0006
# 5672   moz  2004         energy        0.5997       1.2089   585.2830
# 6671   ukr  2004         energy      502.6150     479.4450  9272.7200
# 7101   ben  2007     primaryagr      808.7770       0.3887     0.0024
# 8750   moz  2007         energy        1.3909       0.7836  1119.7600
# 9928   zmb  2007   distribution      318.3260     220.2380    73.9112
# 13168  zmb  2011   distribution      370.6800     200.5300    72.9600
#
#        g_procfoods  g_bevtobacco  g_textiles  g_clothing  ...  h_finance  \
# 2          19.9136        0.5700      7.7880     21.7902  ...     0.0188
# 3591      116.9660       70.6304      3.8296      0.5233  ...     0.0024
# ...

# %%
#e) Las 100 exportaciones de “iso3: tha, kor, phl, ven y deu”, con “g_textiles” mayor a “1” y “g clothing” menor a “1”
filtro_e= df[(df['iso3'] == 'tha') | (df['iso3'] == 'kor') | (df['iso3'] == 'phl') | (df['iso3'] == 'ven') | (df['iso3'] == 'deu') & (df['g_textiles'] > 1) & (df['g_clothing'] < 1)]
print(df_e)
# Out:
#       iso3  year sector_GMatrix  g_primaryagr  g_otherprim   g_energy  \
# 864    kor  1997     primaryagr     8400.3800      19.0981     9.4696
# 865    kor  1997      otherprim      150.0050    2179.5400     7.0809
# 866    kor  1997         energy      157.9300      61.7006  2937.6500
# 867    kor  1997      procfoods      277.5860       7.5520     3.4279
# 868    kor  1997     bevtobacco        5.4563       8.1466     2.7936
# ...    ...   ...            ...           ...          ...        ...
# 13090  ven  2011        finance      107.2300      45.9500  1499.9100
# 13091  ven  2011      insurance       13.2100       5.2000    34.9900
# 13092  ven  2011         obsict      219.1000     177.4700  1517.3600
# 13093  ven  2011      oconsumer        9.5800       9.0200    40.9600
# 13094  ven  2011      oservices       16.2800      14.1900    66.5200
#
#        g_procfoods  g_bevtobacco  g_textiles  g_clothing  ...  h_finance  \
# ...

# %%
#f) Las 15 exportaciones de “year: 2004”, con “h_oservices” mayor a “10”
filtro_f= df[(df['year'] == 2004) & (df['h_oservices'] > 10)]
print(df_f)
# Out:
#      iso3  year sector_GMatrix  g_primaryagr  g_otherprim  g_energy  \
# 3833  alb  2004      oservices        0.2913       0.1102    0.1467
# 3860  are  2004      oservices        0.1888       0.0584   15.8087
# 3885  arg  2004         obsict      251.8390       6.4964   83.9202
# 3887  arg  2004      oservices      202.6470       5.3857   76.9778
# 3914  arm  2004      oservices        2.5615       1.0366    0.6777
# ...   ...   ...            ...           ...          ...       ...
# 6827  zaf  2004      insurance      235.5240     133.2500  132.4490
# 6828  zaf  2004         obsict      272.1790     233.8180  151.5080
# 6830  zaf  2004      oservices       63.6928      25.9981    5.6810
# 6857  zmb  2004      oservices        0.5410       1.0682    5.1792
# 6884  zwe  2004      oservices        9.4795       0.9173    0.5526
#
#       g_procfoods  g_bevtobacco  g_textiles  g_clothing  ...  h_finance  \
# 3833       0.3305        0.0156      0.1665      0.1973  ...     0.0336
# ...

# %%
#g) Todas las exportaciones que no sean de “sector_Gmatrix: machinery“
filtro_g= df[~(df['sector_GMatrix'] == 'machinery')]
print(df_g)
# Out:
#       iso3  year sector_GMatrix  g_primaryagr  g_otherprim  g_energy  \
# 0      alb  1997     primaryagr       93.3774       0.0143    0.2158
# 1      alb  1997      otherprim        0.0521       5.7779    0.0979
# 2      alb  1997         energy       12.8071       3.0441  195.5730
# 3      alb  1997      procfoods        0.8223       0.0041    0.0706
# 4      alb  1997     bevtobacco        0.0022       0.0003    0.0036
# ...    ...   ...            ...           ...          ...       ...
# 13198  zwe  2011        finance       15.7700       0.3200    0.2900
# 13199  zwe  2011      insurance        2.9000       0.0400    0.0300
# 13200  zwe  2011         obsict       18.5100       0.4300    0.3700
# 13201  zwe  2011      oconsumer        3.0600       0.0700    0.0800
# 13202  zwe  2011      oservices       12.1400       1.0900    0.6800
#
#        g_procfoods  g_bevtobacco  g_textiles  g_clothing  ...  h_finance  \
# ...

# %%
#h) Todas las exportaciones que no sean de “Dxshare “ mayor a “0.5”
filtro_h= df[~(df['DXshare'] > 0.5)]
print(df_h)
# Out:
#       iso3  year sector_GMatrix  g_primaryagr  g_otherprim  g_energy  \
# 0      alb  1997     primaryagr       93.3774       0.0143    0.2158
# 1      alb  1997      otherprim        0.0521       5.7779    0.0979
# 3      alb  1997      procfoods        0.8223       0.0041    0.0706
# 4      alb  1997     bevtobacco        0.0022       0.0003    0.0036
# 5      alb  1997       textiles        0.0082       0.0004    0.0028
# ...    ...   ...            ...           ...          ...       ...
# 13198  zwe  2011        finance       15.7700       0.3200    0.2900
# 13199  zwe  2011      insurance        2.9000       0.0400    0.0300
# 13200  zwe  2011         obsict       18.5100       0.4300    0.3700
# 13201  zwe  2011      oconsumer        3.0600       0.0700    0.0800
# 13202  zwe  2011      oservices       12.1400       1.0900    0.6800
#
#        g_procfoods  g_bevtobacco  g_textiles  g_clothing  ...  h_finance  \
# ...

# %%
#i) Todas las exportaciones que sean de “h_oconsumer:“ igual a “0.02” o “h_obsict“ mayor que “10”
filtro_i= df[(df['h_oconsumer'] == 0.02) | (df['h_obsict'] > 10)]
print(df_i)
# Out:
#       iso3  year sector_GMatrix  g_primaryagr  g_otherprim   g_energy  \
# 51     arg  1997         obsict      172.1130       1.8889   125.9700
# 56     aus  1997         energy      264.1910     327.3620  8225.6200
# 63     aus  1997       paperpub       79.4958      42.9939    27.4799
# 71     aus  1997          water       65.8972      26.7741    29.4982
# 73     aus  1997   distribution      560.1380     330.4000   166.1190
# ...    ...   ...            ...           ...          ...        ...
# 13175  zmb  2011      oservices        0.9600       2.9100     9.7900
# 13187  zwe  2011      nonmetmin        0.4400       0.7200     0.2000
# 13198  zwe  2011        finance       15.7700       0.3200     0.2900
# 13200  zwe  2011         obsict       18.5100       0.4300     0.3700
# 13202  zwe  2011      oservices       12.1400       1.0900     0.6800
#
#        g_procfoods  g_bevtobacco  g_textiles  g_clothing  ...  h_finance  \
# ...

# %%
#Convertir archivo filtrado a CSV
filtro_a.to_csv("Actividad 2.3 Filtro_a.csv")
filtro_b.to_csv("Actividad 2.3 Filtro_b.csv")
filtro_c.to_csv("Actividad 2.3 Filtro_c.csv")
filtro_d.to_csv("Actividad 2.3 Filtro_d.csv")
filtro_e.to_csv("Actividad 2.3 Filtro_e.csv")
filtro_f.to_csv("Actividad 2.3 Filtro_f.csv")
filtro_g.to_csv("Actividad 2.3 Filtro_g.csv")
filtro_h.to_csv("Actividad 2.3 Filtro_h.csv")
filtro_i.to_csv("Actividad 2.3 Filtro_i.csv")
